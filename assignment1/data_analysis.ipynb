# %% [markdown]
# <a href="https://colab.research.google.com/github/alierenc/computational-semantics/blob/master/assignment1/data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import pandas as pd

drive.mount('/content/drive')

train_data_path = "/content/drive/MyDrive/DI725 - Transformers and Attention-based Deep Networks/Assignment 1/train.csv"
test_data_path = "/content/drive/MyDrive/DI725 - Transformers and Attention-based Deep Networks/Assignment 1/test.csv"

train_df = pd.read_csv(train_data_path)
test_df = pd.read_csv(test_data_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Info and summary
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 970 entries, 0 to 969
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   issue_area                   970 non-null    object
#  1   issue_category               970 non-null    object
#  2   issue_sub_category           970 non-null    object
#  3   issue_category_sub_category  970 non-null    object
#  4   customer_sentiment           970 non-null    object
#  5   product_category             970 non-null    object
#  6   product_sub_category         970 non-null    object
#  7   issue_complexity             970 non-null    object
#  8   agent_experience_level       970 non-null    object
#  9   agent_experience_level_desc  970 non-null    object
#  10  conversation                 970 non-null    object
# dtypes: object(11)
# memory usage: 83.5+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   issue_area                   30 non-null     object
#  1   issue_category               30 non-null     object
#  2   issue_sub_category           30 non-null     object
#  3   issue_category_sub_category  30 non-null     object
#  4   customer_sentiment           30 non-null     object
#  5   product_category             30 non-null     object
#  6   product_sub_category         30 non-null     object
#  7   issue_complexity             30 non-null     object
#  8   agent_experience_level       30 non-null     object
#  9   agent_experience_level_desc  30 non-null     object
#  10  conversation                 30 non-null     object
# dtypes: object(11)
# memory usage: 2.7+ KB

# %%
train_df.describe()
# Out:
#                        issue_area       issue_category  \
# count                         970                  970
# unique                          6                   40
# top     Cancellations and returns  Return and Exchange
# freq                          277                   92
#
#                                        issue_sub_category  \
# count                                                 970
# unique                                                109
# top     Verification requirement for mobile number or ...
# freq                                                   17
#
#                               issue_category_sub_category customer_sentiment  \
# count                                                 970                970
# unique                                                109                  3
# top     Mobile Number and Email Verification -> Verifi...            neutral
# freq                                                   17                542
#
#        product_category product_sub_category issue_complexity  \
# count               970                  970              970
# unique                3                   50                3
# top          Appliances           Bp Monitor             less
# freq                454                   26              472
#
#        agent_experience_level  \
# count                     970
# unique                      3
# top                    junior
# freq                      490
#
#                               agent_experience_level_desc  \
# count                                                 970
# unique                                                  3
# top     handles customer inquiries independently, poss...
# freq                                                  490
#
#                                           conversation
# count                                              970
# unique                                             968
# top     Agent: You're welcome, Jane. Have a great day!
# freq                                                 3

# %%
test_df.describe()
# Out:
#        issue_area                 issue_category       issue_sub_category  \
# count          30                             30                       30
# unique          6                             16                       22
# top         Order  Order Confirmation and Status  Confirming order status
# freq           12                              6                        5
#
#                               issue_category_sub_category customer_sentiment  \
# count                                                  30                 30
# unique                                                 22                  3
# top     Order Confirmation and Status -> Confirming or...           negative
# freq                                                    5                 10
#
#        product_category product_sub_category issue_complexity  \
# count                30                   30               30
# unique                3                   21                3
# top          Appliances       Vacuum Cleaner             less
# freq                 11                    3               16
#
#        agent_experience_level  \
# count                      30
# unique                      3
# top                    junior
# freq                       17
#
#                               agent_experience_level_desc  \
# count                                                  30
# unique                                                  3
# top     handles customer inquiries independently, poss...
# freq                                                   17
#
#                                              conversation
# count                                                  30
# unique                                                 30
# top     Agent: Thank you for calling BrownBox Customer...
# freq                                                    1
